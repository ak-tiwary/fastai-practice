# %% [markdown]
# <a href="https://colab.research.google.com/github/ak-tiwary/fastai-practice/blob/main/Jaguar_Cheetah_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 719 kB 9.7 MB/s
#      |████████████████████████████████| 4.2 MB 44.8 MB/s
#      |████████████████████████████████| 197 kB 63.8 MB/s
#      |████████████████████████████████| 1.2 MB 50.5 MB/s
#      |████████████████████████████████| 362 kB 48.7 MB/s
#      |████████████████████████████████| 60 kB 7.6 MB/s
#      |████████████████████████████████| 212 kB 71.8 MB/s
#      |████████████████████████████████| 1.1 MB 53.3 MB/s
#      |████████████████████████████████| 86 kB 5.5 MB/s
#      |████████████████████████████████| 140 kB 72.5 MB/s
#      |████████████████████████████████| 596 kB 60.0 MB/s
#      |████████████████████████████████| 127 kB 65.2 MB/s
#      |████████████████████████████████| 94 kB 3.7 MB/s
#      |████████████████████████████████| 144 kB 50.5 MB/s
#      |████████████████████████████████| 271 kB 48.3 MB/s
#      |████████████████████████████████| 6.6 MB 52.3 MB/s
# ...

# %%
from fastbook import *
from fastai.vision.widgets import *
from fastai.vision.all import *

# %% [markdown]
# ## Jaguar vs Cheetah Classifier
#
# Add an image of a jaguar or a cheetah and the model will predict whether it is a jaguar or a cheetah with 90% accuracy.

# %%
path = Path('./gdrive/MyDrive')
learn_inf = load_learner(path/'export.pkl',cpu=True)

# %%
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
def on_data_change(change):
  lbl_pred.value = ''
  img = PILImage.create(btn_upload.data[-1])
  out_pl.clear_output()
  with out_pl: display(img.to_thumb(256,256))
  pred, pred_idx, prob = learn_inf.predict(img)
  lbl_pred.value = f'Prediction: {pred}; Probability: {prob[pred_idx]:.04f}'

# %%
btn_upload.observe(on_data_change,names=['data'])

# %%
display(VBox([widgets.Label('Select the big cat'), btn_upload, out_pl,lbl_pred]))
# Out:
# ...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
